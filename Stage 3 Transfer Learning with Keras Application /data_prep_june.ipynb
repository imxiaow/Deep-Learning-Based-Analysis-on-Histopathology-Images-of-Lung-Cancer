# %%
# June 06-7,2020
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
# Task 1: Based on labeled file: slides --> gene mutation class,
#         Separate tiles into class_kras and class_nokras.
#         - Get the statistics of number of images and number of tiles. 
#         - Rename the image in each class folder to its corresponding class. 

# All tiles: 612822
#     /nfs/home/xwang/Transfer_Learning_April/r2_LUAD_segmentation/LUAD/

# Created:
# --New data folder path:
#         /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder

# --Class – Kras PATH:
#        /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_kras

# --Class – no-kras PATH:
#        /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_nokras
#----------------------------------------------------------------------------------------
# read in all filenames in tiles_data path, - done
# read in the label file for each slide, - done
# get the tile's filename for each class,  -done
# get the statistics of each class, num_image, num_tile -done 
# copy the tile file to its corresponding class folder. - done
# change the file name in each class folder to appropriate one that suitable for Keras input. - done. 
#----------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------
# Task 2: 

# Load datasets [class 1 & class 2] with Keras Application.
# change around the parameters.

# %%
# read in all filenames in tiles_data path, - done
# read in the label file for each slide, - done
# get the tile's filename for each class,  -done
# get the statistics of each class, num_image, num_tile -done 
# copy the tile file to its corresponding class folder. - done
# change the file name in each class folder to appropriate one that suitable for Keras input. - done.

# %%
# read in all filenames in tiles_data path:  
# /nfs/home/xwang/Transfer_Learning_April/r2_LUAD_segmentation/LUAD/

import os

ALL_tile_Folder_PATH = "/nfs/home/xwang/Transfer_Learning_April/r2_LUAD_segmentation/LUAD/"
Tile_filenames = os.listdir(ALL_tile_Folder_PATH)

# %%
# read in the label file for each slide,
# label_r3_2class.txt

import pandas as pd

slides_label_file_PATH = "./labels_r3_2class.txt"
slides_mutation_status = pd.read_csv(slides_label_file_PATH, sep='\t', header=0)

# %%
slides_mutation_status
# Out:
#                                        Unique_SlideIDs KRAS_Mutation
# 0    0x06E1863BA7D14243658B206950527C2A8544E5FA21D8...          KRAS
# 1    0xF207C1FE18C2B10C7DBD5DA8341F519949D5241ADE89...          KRAS
# 2    0x42EE64823D60DD1AC88845E3CED5C13C40975F059E2B...          KRAS
# 3    0x558D387AC34E6CA7FA0836DACA2A4A449B4B19C95FCA...          KRAS
# 4    0x559F30CE4B35000E990FD1B046DED705D8095D3BFE18...          KRAS
# ..                                                 ...           ...
# 515  0x7A3D1FF82AD2D0A7CFE6C9F87D26CAAB1C88BC78EF7B...       No_KRAS
# 516  0x6EB510627F33232F35FFEF3AB681E98A2C3D97FABBA2...       No_KRAS
# 517  0x3FA72403D59DD9457829317F6E898787D4A998E39B71...       No_KRAS
# 518  0x8EC446A405F4DAF71622810082AB0C3C57CA6744F0CF...       No_KRAS
# 519  0xCF5BC51C4EAD6083855213FECC8DA73070CDAE272D4E...       No_KRAS
#
# [520 rows x 2 columns]

# %%
slides_with_kras = slides_mutation_status[slides_mutation_status["KRAS_Mutation"] == "KRAS"]

# %%
slides_with_kras
# Out:
#                                        Unique_SlideIDs KRAS_Mutation
# 0    0x06E1863BA7D14243658B206950527C2A8544E5FA21D8...          KRAS
# 1    0xF207C1FE18C2B10C7DBD5DA8341F519949D5241ADE89...          KRAS
# 2    0x42EE64823D60DD1AC88845E3CED5C13C40975F059E2B...          KRAS
# 3    0x558D387AC34E6CA7FA0836DACA2A4A449B4B19C95FCA...          KRAS
# 4    0x559F30CE4B35000E990FD1B046DED705D8095D3BFE18...          KRAS
# ..                                                 ...           ...
# 104  0x29A1642A71E1235D02DB1D071DBC8FFD5BB66DC385DC...          KRAS
# 105  0x854ACDB346FADB69611561009230E5C212ABAC44D1A5...          KRAS
# 106  0x2B6CB0721204AEDB712210A71045A99DD1910741CB5C...          KRAS
# 107  0x818AB68A434C9C830421B4F7015AF3BAF10645F7A04D...          KRAS
# 108  0x534BD121FD2C8CEFD2298279E4D34D4C0C438CA59951...          KRAS
#
# [109 rows x 2 columns]

# %%
slides_with_nokras = slides_mutation_status[slides_mutation_status["KRAS_Mutation"] == "No_KRAS"]

# %%
slides_with_nokras
# Out:
#                                        Unique_SlideIDs KRAS_Mutation
# 109  0x87990C8A244F13853201884A24DBE62A160277F734F1...       No_KRAS
# 110  0x74F36E8C28554780B06A1CA0DC06A8996AD4FE1FDE11...       No_KRAS
# 111  0x8F07FEEED72794E4FD1835AF997627A64715582E97AE...       No_KRAS
# 112  0x8E2498A1810801E59F31CAE3CE20F287CE4CF7C4B924...       No_KRAS
# 113  0x745AD4EADE6BFF6C74491B57DA2AC169B586B5A8733A...       No_KRAS
# ..                                                 ...           ...
# 515  0x7A3D1FF82AD2D0A7CFE6C9F87D26CAAB1C88BC78EF7B...       No_KRAS
# 516  0x6EB510627F33232F35FFEF3AB681E98A2C3D97FABBA2...       No_KRAS
# 517  0x3FA72403D59DD9457829317F6E898787D4A998E39B71...       No_KRAS
# 518  0x8EC446A405F4DAF71622810082AB0C3C57CA6744F0CF...       No_KRAS
# 519  0xCF5BC51C4EAD6083855213FECC8DA73070CDAE272D4E...       No_KRAS
#
# [411 rows x 2 columns]

# %%
# # get the slide's ID for each class, 
# lst slides ID with KRAS
kras_slidesID_lst = slides_with_kras["Unique_SlideIDs"].tolist()
# lst slides ID with No_KRAS
nokras_slidesID_lst = slides_with_nokras["Unique_SlideIDs"].tolist()

# %%
print(len(kras_slidesID_lst))
print(len(nokras_slidesID_lst))
# Out:
# 109
# 411

# %%
# get the tile's filename for each class,

print(Tile_filenames[0:9])
# Out:
# ['test_0x9DC5E3EA954B783C07B3048FACA689BCE603D5A3367A40C501F1F9CE4D1873E3_1x8JDFE91W46_31_47.jpeg', 'test_0x57DF8932313E8A4CC8A0A00AABB98618DB55D5587D241ADCD7A9B9A406876EC3_1xPWRXES2P2G_24_67.jpeg', 'test_0xC556E143D291C472A01B9ED41D52588DD1A4E9FD82733DF1C1F02AF1CE7011C3_1xQINHZ9E5JC_30_13.jpeg', 'test_0x162481B498E3969695FAE915226F3CF8DF1C0B494757027022DC28D507490511_1x4PYAQHHZD6_34_24.jpeg', 'test_0x2B2C1385C0EEF8D39E56614A7F9BCB52DDAAE9574C4B7A4158D29927940ED17A_1x3D83AGAXAA_38_71.jpeg', 'test_0x923F6F04D196426CFC017320FD2E466F3E2BB7837CB3A3453CFA159CC5C240C4_1xZ7JRZ1EAJA_40_17.jpeg', 'test_0xD101AC48A85D227B0795A7FE777B31633729D4AFDF3BD2B470CC3BDC43AE2F83_1xMDGQ2VIXOF_30_74.jpeg', 'test_0x11DA9EDCC4B149A6162AEDE368E8F6A6168779F0E09FA3B87E6C30A757383995_1x5BDAN220TI_22_18.jpeg', 'test_0x60A7FC306EA4A7E9594543DC7FAC37B6A611046A97703ECDEE59AE1F0A96612B_1xHPW33WX94X_9_44.jpeg']

# %%
kras_class_tile_filenames = []
nokras_class_tile_filenames = []

kras_class_count_tile = 0
nokras_class_count_tile = 0


for fname in Tile_filenames:
    if "0x" in fname and "_1x" in fname and ".jpeg" in fname:
        fpartone = fname.split("_")[1]
        fparttwo = fname.split("_")[2]
        f_nameadd = fpartone + "_" + fparttwo
        
        if f_nameadd in kras_slidesID_lst:
            kras_class_count_tile +=1
            kras_class_tile_filenames.append(fname)
            
        if f_nameadd in nokras_slidesID_lst:
            nokras_class_count_tile +=1
            nokras_class_tile_filenames.append(fname)

# %%
kras_class_count_tile
# Out:
# 132439

# %%
nokras_class_count_tile
# Out:
# 480383

# %%
132439 + 480383
# Out:
# 612822

# %%
print(len(kras_class_tile_filenames))
print(len(nokras_class_tile_filenames))
# Out:
# 132439
# 480383

# %%
132439/612822
# Out:
# 0.2161133249132701

# %%
kras_class_tile_filenames[0:5]
# Out:
# ['test_0x9DC5E3EA954B783C07B3048FACA689BCE603D5A3367A40C501F1F9CE4D1873E3_1x8JDFE91W46_31_47.jpeg',
#  'test_0xCA9B44D8ADF16E2B22BC127AB2F6E7116F1147E244AA5A5B0E45DA02DCEB919A_1xTDSF31MYAF_54_88.jpeg',
#  'test_0xB1C1133F08A9409429BFC4958AB55BEDE044CF138531BF48A7D2B757A06B4D3C_1xHNVGQ0OIKS_50_47.jpeg',
#  'test_0x90A179FF06CC574F10109FE676486FBB7A1C3DC0D80A0A636C189CF83D1C8106_1xSU63128FFJ_12_46.jpeg',
#  'test_0xD1E7CD79E8E0F519F4F850AEED25256D3EB29AB8DE9CC454B324E407B8344A70_1xWJ262S3P4I_26_5.jpeg']

# %%
# copy the tile file to its corresponding class folder. 

# --Class – Kras PATH:
#        /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_kras

# --Class – no-kras PATH:
#        /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_nokras

# original path: 
#        /nfs/home/xwang/Transfer_Learning_April/r2_LUAD_segmentation/LUAD/

import shutil

original_file_folder_path = "/nfs/home/xwang/Transfer_Learning_April/r2_LUAD_segmentation/LUAD/"
#kras_class_folder_path = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_kras/"


#for tile_file in kras_class_tile_filenames:
#    target_file_path = kras_class_folder_path + tile_file
#    orginal_file_path = original_file_folder_path + tile_file
#    shutil.copy(orginal_file_path, target_file_path)
    
# /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_kras


#nokras_class_tile_filenames
# /nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_nokras

# %%
#nokras_class_folder_path = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_nokras/"

#for tile_file in nokras_class_tile_filenames:
#    target_file_path = nokras_class_folder_path + tile_file
#    orginal_file_path = original_file_folder_path + tile_file
#    shutil.copy(orginal_file_path, target_file_path)

# %%
# change the file name in each class folder to appropriate one that suitable for Keras input. 


# Supposed you have image files sorted by class in different folders, like this:
'''
main_directory/
...class_a/
......a_image_1.jpg
......a_image_2.jpg
...class_b/
......b_image_1.jpg
......b_image_2.jpg
'''
# Out:
# '\nmain_directory/\n...class_a/\n......a_image_1.jpg\n......a_image_2.jpg\n...class_b/\n......b_image_1.jpg\n......b_image_2.jpg\n'

# %%
kras_class_folder_path = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_kras/"
nokras_class_folder_path = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_nokras/"

# change the image/tile filename to --> < kras_image_1.jpg > || < nokras_image_1.jpg >

# os.rename(r'file path\OLD file name.file type', r'file path\NEW file name.file type')

import os

# rename files in kras class folder
#tile_filenames_kras = os.listdir(kras_class_folder_path)

#for fname_kras in tile_filenames_kras:
#    if "0x" in fname_kras and "_1x" in fname_kras and ".jpeg" in fname_kras:
#        remain_fname = fname_kras.split("test")[1]
#        new_fname = "kras" + remain_fname
#        orginal_f_path = kras_class_folder_path + fname_kras
#        new_f_path = kras_class_folder_path + new_fname
#        os.rename(orginal_f_path, new_f_path)

# %%
#test_split = 'test_0x9DC5E3EA954B783C07B3048FACA689BCE603D5A3367A40C501F1F9CE4D1873E3_1x8JDFE91W46_31_47.jpeg'
#print("kras" + test_split.split("test")[1])

# %%
# rename files in nokras class folder
#tile_filenames_nokras = os.listdir(nokras_class_folder_path)

#for fname_nokras in tile_filenames_nokras:
#    if "0x" in fname_nokras and "_1x" in fname_nokras and ".jpeg" in fname_nokras:
#        remain_fname = fname_nokras.split("test")[1]
#        new_fname = "nokras" + remain_fname
#        orginal_f_path_nokras = nokras_class_folder_path + fname_nokras
#        new_f_path_nokras = nokras_class_folder_path + new_fname
#        os.rename(orginal_f_path_nokras, new_f_path_nokras)

# %%
#----------------------------------------------------------------------------------------
# Task 2: 

# Load datasets [class 1 & class 2] with Keras Application.
# change around the parameters. 
# Data loading 

dataset_Keras_PATH = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/"
kras_class_folder_path = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_kras/"
nokras_class_folder_path = "/nfs/home/xwang/Keras_Transfer_Learning_June/Dataset_Keras_Folder/class_nokras/"

# intall Tensorflow 2.0
# pip install tensorflow
#Downloading # https://files.pythonhosted.org/packages/4c/1a/0d79814736cfecc825ab8094b39648cc9c46af7af1bae839928acb73b4dd/
# tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2MB)

# pip install tf-nightly
# Downloading https://files.pythonhosted.org/packages/d2/6d/b59108d17153887025a962162b48556593545878f7ede21cf1cc023a6613/
#  tf_nightly-2.3.0.dev20200605-cp37-cp37m-manylinux2010_x86_64.whl (526.2MB)


import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input
from tensorflow.keras.optimizers import Adam

#https://keras.io/getting_started/intro_to_keras_for_engineers/#data-loading-amp-preprocessing
'''
tf.keras.preprocessing.image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
)
'''

# Create trainning dataset.
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(dataset_Keras_PATH, validation_split=0.3, subset="training", seed=2020, batch_size=200, image_size=(512, 512))
# create validation dataset. 
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(dataset_Keras_PATH, validation_split=0.3, subset="validation", seed=2020, batch_size=200,image_size=(512, 512))


# For demonstration, iterate over the batches yielded by the dataset.
#for data, labels in dataset:
#    print(data.shape)  # (200, 512, 512, 3)
#    print(data.dtype)  # <dtype: 'float32'>
#    print(labels.shape)  # (200,)
#    print(labels.dtype)  # <dtype: 'int32'>
# Out:
# Found 612822 files belonging to 2 classes.
# Using 428976 files for training.
# Found 612822 files belonging to 2 classes.
# Using 183846 files for validation.

# %%
import matplotlib.pyplot as plt
# visualize the data
# https://keras.io/examples/vision/image_classification_from_scratch/

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
# https://keras.io/guides/transfer_learning/
#---------------------------------------------------
# Typical transfer learning workflow:
# - Instantiate a base model and load pre-trained weights into it.
# - Freeze all layers in the base model by setting trainable = False.
# - Create a new model on top of the output of one (or several) layers from the base model.
# - Train your new model on your new dataset.
#---------------------------------------------------
"""
tf.keras.applications.InceptionResNetV2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    **kwargs
)
"""

#https://github.com/jkjung-avt/keras-cats-dogs-tutorial/blob/master/train_inceptionresnetv2.py
#https://github.com/yuyang-huang/keras-inception-resnet-v2
# Out:
# '\ntf.keras.applications.InceptionResNetV2(\n    include_top=True,\n    weights="imagenet",\n    input_tensor=None,\n    input_shape=None,\n    pooling=None,\n    classes=1000,\n    classifier_activation="softmax",\n    **kwargs\n)\n'

# %%
# Instantiate a base model and load pre-trained weights into it
base_model = InceptionResNetV2(
    include_top=False,
    weights='imagenet',
    input_shape=(512, 512, 3)
)

# %%
# Freeze base model
base_model.trainable = False

# %%
# - Create a new model on top of the output of one (or several) layers from the base model.

inputs = keras.Input(shape=(512, 512, 3))
x = base_model(inputs, training=False)

x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)

outputs = keras.layers.Dense(2, activation='softmax', name='softmax')(x)
current_model = keras.Model(inputs, outputs)
current_model.summary()

#Cross-entropy is the default loss function to use for binary classification problems.
#It is intended for use with binary classification where the target values are in the set {0, 1}.
loss_fn = keras.losses.BinaryCrossentropy()
optimizer = keras.optimizers.Adam()#learning rate is default to 0.001
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# inception_resnet_v2 (Functio (None, 14, 14, 1536)      54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1536)              0
# _________________________________________________________________
# softmax (Dense)              (None, 2)                 3074
# ...
# Total params: 54,339,810
# Trainable params: 3,074
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
#source: https://github.com/kapil-varshney/utilities/blob/master/training_plot/trainingplot.py
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import numpy as np

class TrainingPlot(keras.callbacks.Callback):

    def __init__(self, filename='output/training_plot.jpg'):
        self.filename = filename

    # This function is called when the training begins
    def on_train_begin(self, logs={}):
        # Initialize the lists for holding the logs, losses and accuracies
        self.losses = []
        self.acc = []
        self.val_losses = []
        self.val_acc = []
        self.logs = []

    # This function is called at the end of each epoch
    def on_epoch_end(self, epoch, logs={}):

        # Append the logs, losses and accuracies to the lists
        self.logs.append(logs)
        self.losses.append(logs.get('loss'))
        self.acc.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        self.val_acc.append(logs.get('val_acc'))

        # Before plotting ensure at least 2 epochs have passed
        if len(self.losses) > 1:

            N = np.arange(0, len(self.losses))

            # You can chose the style of your preference
            # print(plt.style.available) to see the available options
            plt.style.use("seaborn")

            # Plot train loss, train acc, val loss and val acc against epochs passed
            plt.figure()
            plt.plot(N, self.losses, label = "train_loss")
            plt.plot(N, self.acc, label = "train_acc")
            plt.plot(N, self.val_losses, label = "val_loss")
            plt.plot(N, self.val_acc, label = "val_acc")
            plt.title("Training Loss and Accuracy [Epoch {}]".format(epoch))
            plt.xlabel("Epoch #")
            plt.ylabel("Loss/Accuracy")
            plt.legend()
            # Make sure there exists a folder called output in the current directory
            # or replace 'output' with whatever direcory you want to put in the plots
            plt.savefig(self.filename)
            plt.close()

# %%
# - Train your new model on your new dataset.

# Create an instance of the TrainingPlot class with the filename.
plot_losses = TrainingPlot()

epochs = 50

callbacks_plotloss = [
    #keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
    plot_losses
]

current_model.compile(
    optimizer=optimizer,
    loss=loss_fn,
    metrics=["accuracy"],
)

#Configure the dataset for performance
train_dataset = train_dataset.prefetch(buffer_size=200)
validation_dataset = validation_dataset.prefetch(buffer_size=200)

#Train the model using callback to the TrainingPlot class object
current_model.fit(
    train_dataset, epochs=epochs, callbacks=callbacks_plotloss, validation_data=validation_dataset,
)
# Out:
# Epoch 1/50
#  143/2145 [=>............................] - ETA: 2:53:23 - loss: 7.6927 - accuracy: 0.2172
