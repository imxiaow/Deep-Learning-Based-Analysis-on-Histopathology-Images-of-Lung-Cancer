# %%
from matplotlib import pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import sys

# %%
print("Python Version: " + '{0[0]}.{0[1]}'.format(sys.version_info))
print("Matplotlib Version: " + matplotlib.__version__)
# Out:
# Python Version: 3.7
# Matplotlib Version: 2.2.3

# %%
training_loss_f_path = "./training_loss.txt"
training_loss = pd.read_csv(training_loss_f_path, delimiter =" ", header=None)

# %%
training_loss
# Out:
#               0                 1     2       3     4  5     6     7   \
# 0     2020-05-01  17:05:06.307927:  step      0,  loss  =  1.28  (3.4
# 1     2020-05-01  17:14:01.629100:  step     10,  loss  =  1.08  (9.0
# 2     2020-05-01  17:21:21.414726:  step     20,  loss  =  1.00  (9.1
# 3     2020-05-01  17:28:39.317935:  step     30,  loss  =  0.94  (9.0
# 4     2020-05-01  17:35:57.994501:  step     40,  loss  =  0.95  (9.2
# 5     2020-05-01  17:43:23.825233:  step     50,  loss  =  0.96  (8.7
# 6     2020-05-01  17:50:46.523085:  step     60,  loss  =  0.93  (9.1
# 7     2020-05-01  17:58:12.609461:  step     70,  loss  =  0.98  (9.0
# 8     2020-05-01  18:05:42.887666:  step     80,  loss  =  0.93  (8.9
# 9     2020-05-01  18:13:10.867933:  step     90,  loss  =  0.90  (8.9
# 10    2020-05-01  18:20:39.171322:  step    100,  loss  =  0.97  (8.9
# 11    2020-05-01  18:28:55.390551:  step    110,  loss  =  0.88  (8.9
# ...

# %%
training_loss[6]
# Out:
# 0       1.28
# 1       1.08
# 2       1.00
# 3       0.94
# 4       0.95
# 5       0.96
# 6       0.93
# 7       0.98
# 8       0.93
# 9       0.90
# 10      0.97
# 11      0.88
# 12      0.95
# 13      0.99
# 14      0.89
# 15      0.93
# 16      0.88
# 17      0.87
# 18      0.87
# 19      0.93
# 20      0.88
# 21      1.01
# 22      0.93
# 23      0.87
# 24      0.88
# 25      0.91
# 26      0.88
# 27      0.87
# 28      0.87
# 29      0.88
#         ...
# 4695    0.65
# 4696    0.72
# 4697    0.65
# 4698    0.70
# 4699    0.70
# 4700    0.74
# 4701    0.68
# 4702    0.69
# 4703    0.69
# 4704    0.72
# 4705    0.66
# 4706    0.70
# 4707    0.71
# 4708    0.70
# 4709    0.66
# 4710    0.81
# 4711    0.73
# 4712    0.71
# 4713    0.66
# 4714    0.70
# 4715    0.69
# 4716    0.72
# 4717    0.66
# 4718    0.66
# 4719    0.70
# 4720    0.69
# 4721    0.66
# 4722    0.73
# 4723    0.68
# 4724    0.68
# Name: 6, Length: 4725, dtype: float64

# %%
plt.plot(pd.DataFrame(np.arange(0,47250,10), columns=["step"]), training_loss[6])
plt.title("training loss")
# Out:
# Text(0.5,1,'training loss')
